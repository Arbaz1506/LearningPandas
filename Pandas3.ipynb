# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Finding missing Data

# %%
data = {
    "A": [10, 20, np.nan, 40],
    "B": [np.nan, 25, 35, 45],
    "C": [15, np.nan, 30, np.nan],
    "D": [np.nan, 22, 32, 42]
}


df = pd.DataFrame(data)
df
# Out:
#       A     B     C     D
# 0  10.0   NaN  15.0   NaN
# 1  20.0  25.0   NaN  22.0
# 2   NaN  35.0  30.0  32.0
# 3  40.0  45.0   NaN  42.0

# %%
#finding nan value
df.isna()
# Out:
#        A      B      C      D
# 0  False   True  False   True
# 1  False  False   True  False
# 2   True  False  False  False
# 3  False  False   True  False

# %%
#To find total Nan value
df.isna().sum()
# Out:
# A    1
# B    1
# C    2
# D    1
# dtype: int64

# %%
# Checks for NaN values in the DataFrame
# Returns True for columns that contain at least one NaN value
df.isna().any()
# Out:
# A    True
# B    True
# C    True
# D    True
# dtype: bool

# %%
# Checks for NaN values row-wise
# Returns True for rows that contain at least one NaN value
df.isna().any(axis=1)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# dtype: bool

# %% [markdown]
# Removing missing data

# %%
df
# Out:
#       A     B     C     D
# 0  10.0   NaN  15.0   NaN
# 1  20.0  25.0   NaN  22.0
# 2   NaN  35.0  30.0  32.0
# 3  40.0  45.0   NaN  42.0

# %%
#This will remove all the rows which have Nan value
df.dropna()
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %% [markdown]
# Filling missing value

# %%
df
# Out:
#       A     B     C     D
# 0  10.0   NaN  15.0   NaN
# 1  20.0  25.0   NaN  22.0
# 2   NaN  35.0  30.0  32.0
# 3  40.0  45.0   NaN  42.0

# %%
# Replace all missing (NaN) values in the DataFrame with 0
df.fillna(0)
# Out:
#       A     B     C     D
# 0  10.0   0.0  15.0   0.0
# 1  20.0  25.0   0.0  22.0
# 2   0.0  35.0  30.0  32.0
# 3  40.0  45.0   0.0  42.0

# %%
values- ['A':0, 'B':100, 'C':7,'D':98]
df.fillna(value(values))
# Out:
#   Cell In[16], line 1
#     values- ['A':0, 'B':100, 'C':7,'D':98]
#                 ^
# SyntaxError: invalid syntax
